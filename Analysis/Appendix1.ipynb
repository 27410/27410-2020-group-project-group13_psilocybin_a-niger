# %% [markdown]
# ![calc1.png](attachment:bc51a547-ae42-41e0-9484-30c8aab25e2f.png)

# %% [markdown]
# ![calc2.png](attachment:d7952941-21c4-4104-bcad-12d39abf282b.png)

# %% [markdown]
# ![calc3.png](attachment:619d35df-ccf5-42c3-bcf2-ec57bd731c68.png)
