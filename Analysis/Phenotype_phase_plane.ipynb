# %% [markdown]
# # Phenotype phase plane analysis

# %%
# %run 01-model.ipynb

from cobra.flux_analysis.phenotype_phase_plane import production_envelope, add_envelope
from cobra.flux_analysis.phenotype_phase_plane import calculate_phenotype_phase_plane
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-bd17ab627079> in <module>
#       2
#       3 from cobra.flux_analysis.phenotype_phase_plane import production_envelope, add_envelope
# ----> 4 from cobra.flux_analysis.phenotype_phase_plane import calculate_phenotype_phase_plane
#       5
#
# ImportError: cannot import name 'calculate_phenotype_phase_plane'

# %% [markdown]
# #### Defining the glucose content in the YEPD media

# %%
YEPDmedium = model.medium
YEPDmedium['BOUNDARY_GLCe'] = 20
model.reactions.BOUNDARY_GLCe.bounds = -20, 1000

# %%
ppp = production_envelope(model,
                    reactions=[model.reactions.BOUNDARY_GLCe],
                    objective=model.reactions.DRAIN_Biomass)
ppp
# Out:
#     carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 1   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 2   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 3   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 4   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 5   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 6   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 7   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 8   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 9   BOUNDARY_GLCe           0.0                   0.0                 0.0
# 10  BOUNDARY_GLCe           0.0                   0.0                 0.0
# 11  BOUNDARY_GLCe           0.0                   0.0                 0.0
# ...

# %%
ppp.plot(x='BOUNDARY_GLCe', y='flux_maximum')
# Out:
# <AxesSubplot:xlabel='BOUNDARY_GLCe'>

# %%
ppp = production_envelope(model,
                    reactions=[model.reactions.BOUNDARY_GLCe],
                    objective=model.reactions.psiM)
ppp
# Out:
#     carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 1   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 2   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 3   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 4   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 5   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 6   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 7   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 8   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 9   BOUNDARY_GLCe           0.0                   0.0                 NaN
# 10  BOUNDARY_GLCe           0.0                   0.0                 NaN
# 11  BOUNDARY_GLCe           0.0                   0.0                 NaN
# ...

# %%
ppp.plot(x='BOUNDARY_GLCe', y='flux_maximum')
# Out:
# <AxesSubplot:xlabel='BOUNDARY_GLCe'>

# %%
data = calculate_phenotype_phase_plane(model, "BOUNDARY_GLCe", "BOUNDARY_O2e")
data.plot_matplotlib();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-afe581b69b31> in <module>
# ----> 1 data = calculate_phenotype_phase_plane(model, "BOUNDARY_GLCe", "BOUNDARY_O2e")
#       2 data.plot_matplotlib();
#
# NameError: name 'calculate_phenotype_phase_plane' is not defined
